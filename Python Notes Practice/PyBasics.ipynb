# %%
Python Intorduction
1.Variables
2.Data Types
3.Operators
4.Conditional Statements
5.Loops,Elsesuite
6.Functions,Prebuilt-functions
7.Modules and Packages
8.Exception Handling
9.File Handling
10.List Methods
11.Tuple Methods
12.Set Methods
13.Dict Methods
14.String Methods
15.ASCII CODES and Formatting Strings,Escape Squen
16.Generators,Iterators,Decorators
17.Regular Expressions
18.Oops (Encapsulation,Inheritance,Abstraction,Polymorphism)
19.Access Modifiers
20.Duck Typing

Advance Python
1.Multi-Threading
2.DSA Modules
3.Date Time Module
4.Maths Modules
5.OS Modules
6.Numpy
7.Pandas
