# %%
# 1.Check the whether the number is eve or odd 
number = int(input("Enter the number: "))
if number % 2 == 0:
    print(number ,"is even number")
else:
    print(number,"is odd number")
# Out:
# Enter the number:  7
# 7 is odd number

# %%
#2.Print all even or odd numbers based up on the number is given by user
number = int(input('Enter the number'))
for n in range(number,101):
   if n % 2 == 0:
     print(n,"is a even number",end=",")
   else:
     print(n,"is a odd number",end=",")
# Out:
# Enter the number 5
# 5 is a odd number,6 is a even number,7 is a odd number,8 is a even number,9 is a odd number,10 is a even number,11 is a odd number,12 is a even number,13 is a odd number,14 is a even number,15 is a odd number,16 is a even number,17 is a odd number,18 is a even number,19 is a odd number,20 is a even number,21 is a odd number,22 is a even number,23 is a odd number,24 is a even number,25 is a odd number,26 is a even number,27 is a odd number,28 is a even number,29 is a odd number,30 is a even number,31 is a odd number,32 is a even number,33 is a odd number,34 is a even number,35 is a odd number,36 is a even number,37 is a odd number,38 is a even number,39 is a odd number,40 is a even number,41 is a odd number,42 is a even number,43 is a odd number,44 is a even number,45 is a odd number,46 is a even number,47 is a odd number,48 is a even number,49 is a odd number,50 is a even number,51 is a odd number,52 is a even number,53 is a odd number,54 is a even number,55 is a odd number,56 is a even number,57 is a odd number,58 is a even number,59 is a odd number,60 is a even number,61 is a odd number,62 is a even number,63 is a odd number,64 is a even number,65 is a odd number,66 is a even number,67 is a odd number,68 is a even number,69 is a odd number,70 is a even number,71 is a odd number,72 is a even number,73 is a odd number,74 is a even number,75 is a odd number,76 is a even number,77 is a odd number,78 is a even number,79 is a odd number,80 is a even number,81 is a odd number,82 is a even number,83 is a odd number,84 is a even number,85 is a odd number,86 is a even number,87 is a odd number,88 is a even number,89 is a odd number,90 is a even number,91 is a odd number,92 is a even number,93 is a odd number,94 is a even number,95 is a odd number,96 is a even number,97 is a odd number,98 is a even number,99 is a odd number,100 is a even number,

# %%
#3.Leap Year
Year = int(input("Enter the number: "))
if Year % 100 == 0 and Year % 400 == 0:
    print(Year,"is a Leap Year")
elif Year % 4 == 0 and Year % 100 != 0:
    print(Year,"is a Leap Year")
else:
    print(Year,"is not a Leap Year")
